# %%
 # %pip install yahoo-finance
# Out:
# Requirement already satisfied: yahoo-finance in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (1.4.0)
# Requirement already satisfied: pytz in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yahoo-finance) (2024.2)
# Requirement already satisfied: simplejson in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yahoo-finance) (3.19.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.1.2)
# Requirement already satisfied: requests>=2.31 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.31->yfinance) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

# %%
d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=730)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
# Price        Date          Open          High           Low         Close  \
# Ticker                  BTC-USD       BTC-USD       BTC-USD       BTC-USD
# 0      2022-12-09  17232.148438  17280.546875  17100.835938  17133.152344
# 1      2022-12-10  17134.220703  17216.826172  17120.683594  17128.724609
# 2      2022-12-11  17129.710938  17245.634766  17091.820312  17104.193359
# 3      2022-12-12  17102.500000  17212.564453  16899.394531  17206.437500
# 4      2022-12-13  17206.441406  17930.085938  17111.763672  17781.318359
#
# Price      Adj Close       Volume
# Ticker       BTC-USD      BTC-USD
# 0       17133.152344  20328426366
# 1       17128.724609  12706781969
# 2       17104.193359  14122486832
# 3       17206.437500  19617581341
# 4       17781.318359  26634741631

# %%
data.shape
# Out:
# (730, 7)

# %%
# %pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (2.21.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (2.21.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from nbformat) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tuğçe\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\tuğçe\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"], open=data["Open"], high=data["High"],low=data["Low"], close=data["Close"])])
figure.update_layout(title = "Bitcoin Price Analysis", xaxis_rangeslider_visible=False)
figure.show()
